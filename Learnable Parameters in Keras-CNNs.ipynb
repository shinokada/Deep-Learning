# %% [markdown]
# ## Learnable Parameters

# %%
from keras import Sequential
from keras.layers import Dense, Activation
from keras.layers.core import Dense, Flatten
from keras.layers.convolutional import *
from keras.layers.pooling import *

# %%
model = Sequential([
    Conv2D(2, kernel_size=(3, 3), input_shape=(20,20,3), activation='relu', padding='same'),
    Conv2D(3, kernel_size=(3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2,2), strides=2),
    Flatten(),
    Dense(2, activation='softmax')
])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 20, 20, 2)         56
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 20, 20, 3)         57
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 3)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 300)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 602
# =================================================================
# Total params: 715
# Trainable params: 715
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.get_weights()
# Out:
# [array([[[[-0.2960065 , -0.01769528],
#           [-0.12167257,  0.18061513],
#           [ 0.16988242, -0.16186409]],
#
#          [[-0.17101339, -0.23876074],
#           [-0.07922605,  0.35123968],
#           [ 0.36407208, -0.03924748]],
#
#          [[-0.0619525 ,  0.12771404],
#           [ 0.14078009, -0.3604507 ],
#           [-0.1276949 , -0.12698206]]],
#
#
#         [[[ 0.14801192,  0.24456471],
#           [ 0.35558563,  0.19465297],
#           [-0.1965821 , -0.04322082]],
#
#          [[ 0.09314176, -0.13035226],
#           [-0.25877672, -0.33217403],
#           [-0.20854668, -0.3061528 ]],
#
#          [[-0.18092713, -0.28538716],
#           [-0.33521473, -0.08687332],
#           [-0.06833428, -0.00285846]]],
#
#
#         [[[-0.26884237,  0.17154145],
#           [ 0.21160442,  0.21622258],
#           [-0.22429036,  0.05591631]],
#
#          [[ 0.26937753,  0.28162158],
#           [ 0.3075083 ,  0.27259535],
#           [ 0.10770261, -0.12145884]],
#
#          [[-0.26672643,  0.05622581],
#           [ 0.31492037, -0.28618523],
#           [-0.22707483,  0.06612346]]]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[[[ 0.13869965,  0.03555977, -0.01626125],
#           [ 0.10099512, -0.16665691,  0.12895262]],
#
#          [[-0.15511204,  0.01182798, -0.34328318],
#           [-0.32284874, -0.10409638,  0.28765136]],
#
#          [[-0.28759983,  0.2452718 , -0.23455007],
#           [ 0.04812121, -0.09071946, -0.02431595]]],
#
#
#         [[[ 0.29219884,  0.3181138 , -0.05897945],
#           [-0.15746051, -0.24142271, -0.07733551]],
#
#          [[ 0.34128886,  0.05518034,  0.31471086],
#           [ 0.23712063, -0.21715203, -0.3113534 ]],
#
#          [[ 0.36105043,  0.24003124, -0.02512768],
#           [ 0.28340292, -0.14847516,  0.05775794]]],
#
#
#         [[[ 0.18871737,  0.09937739,  0.2392922 ],
#           [ 0.05043861, -0.03193912, -0.19013849]],
#
#          [[ 0.23006338, -0.2869273 ,  0.07960093],
#           [-0.02709755,  0.16547692, -0.11033183]],
#
#          [[-0.03033218, -0.22107199,  0.26997465],
#           [ 0.2259106 ,  0.3595701 , -0.3442147 ]]]], dtype=float32),
#  array([0., 0., 0.], dtype=float32),
#  array([[-0.04469366, -0.00908873],
#         [-0.04426685,  0.06479065],
#         [-0.02336808, -0.05662413],
#         ...,
#         [ 0.06938398, -0.02167591],
#         [ 0.0137626 ,  0.00636922],
#         [ 0.04257455,  0.04232157]], dtype=float32),
#  array([0., 0.], dtype=float32)]
