# %%
# %matplotlib inline

# %%
import numpy as np
from matplotlib import pyplot as plt

random_image = np.random.random([5, 5])

plt.imshow(random_image, cmap='gray', interpolation='nearest');

print(random_image)
type(random_image)
random_image.tofile("a.csv")
# Out:
# [[0.70452644 0.02911578 0.92514007 0.00874265 0.47218708]
#  [0.58343449 0.2935681  0.72816817 0.95560717 0.29164497]
#  [0.14263695 0.60235367 0.41742715 0.99170777 0.14834841]
#  [0.42975035 0.35326281 0.3170439  0.67839106 0.22733823]
#  [0.40626317 0.31577543 0.99975659 0.1247773  0.87298699]]

# %%
from skimage import data

coins = data.coins()

print(type(coins), coins.dtype, coins.shape)
plt.imshow(coins, cmap='gray', interpolation='nearest');
# Out:
# <class 'numpy.ndarray'> uint8 (303, 384)

# %%
cat = data.chelsea()
print("Shape:", cat.shape)
print("Values min/max:", cat.min(), cat.max())

plt.imshow(cat, interpolation='nearest');
# Out:
# Shape: (300, 451, 3)
# Values min/max: 0 231

# %%
cat.tofile("pic.bin")

#np.savetxt('pic.csv', cat2d, delimiter=',')
#print cat.fromfile("pic.bin", dtype=cat.int64)
