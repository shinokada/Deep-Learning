# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import *
from keras import backend as K

import tensorflow as tf

# Set some parameters
IMG_WIDTH = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 3
TRAIN_PATH = '/Users/wajdiahmed/Kaggle/stage1_train/'
DEV_PATH = '/Users/wajdiahmed/Kaggle/stage1_dev/'
TEST_PATH = '/Users/wajdiahmed/Kaggle/stage1_test/'


warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %%
# Get train, dev and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
dev_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %%
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                      preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)
    Y_train[n] = mask

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# 100%|██████████| 670/670 [06:26<00:00,  1.73it/s]
# Getting and resizing test images ...
# 100%|██████████| 65/65 [00:05<00:00, 12.98it/s]
# Done!

# %%
# Check if training data looks all right
ix = random.randint(0, len(train_ids))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
# Out:
# /Users/wajdiahmed/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
# Define IoU metric
    
def iou_coef(y_true, y_pred, smooth=1):
   
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    union = K.sum((y_true,-1) + K.sum(y_pred,-1) - intersection)
   
    return  (intersection + smooth) / (union + smooth)

def iou_coef_loss(y_true, y_pred):
    return -iou_coef(y_true, y_pred)

# Define IoU metric
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        #y_pred_ = tf.to_int32(y_pred &gt; t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2, y_true)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# Metric function https://github.com/kamalkraj/DATA-SCIENCE-BOWL-2018/blob/master/Data_Science_Bowl_2018.ipynb
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Loss funtion
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def iou(box1, box2):
    """Implement the intersection over union (IoU) between box1 and box2
    
    Arguments:
    box1 -- first box, list object with coordinates (x1, y1, x2, y2)
    box2 -- second box, list object with coordinates (x1, y1, x2, y2)
    """

    # Calculate the (y1, x1, y2, x2) coordinates of the intersection of box1 and box2. Calculate its Area.
    ### START CODE HERE ### (≈ 5 lines)
    xi1 = np.max([box1[0], box2[0]])
    yi1 = np.max([box1[1], box2[1]])
    xi2 = np.min([box1[2], box2[2]])
    yi2 = np.min([box1[3],box2[3]])
    inter_area = max((yi2-yi1),0) * max((xi2-xi1),0)
    ### END CODE HERE ###    

    # Calculate the Union area by using Formula: Union(A,B) = A + B - Inter(A,B)
    ### START CODE HERE ### (≈ 3 lines)
    box1_area = (box1[3]-box1[1]) * (box1[2] - box1[0])
    box2_area = (box2[3]-box2[1]) * (box2[2] - box2[0])
    union_area = box1_area + box2_area - inter_area
    ### END CODE HERE ###
    
    # compute the IoU
    ### START CODE HERE ### (≈ 1 line)
    iou = inter_area/union_area
    ### END CODE HERE ###
    
    return iou

# %%
# Build U-Net model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(8, (3, 3), activation='relu', padding='same') (s)
c1 = Conv2D(8, (3, 3), activation='relu', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(16, (3, 3), activation='relu', padding='same') (p1)
c2 = Conv2D(16, (3, 3), activation='relu', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(32, (3, 3), activation='relu', padding='same') (p2)
c3 = Conv2D(32, (3, 3), activation='relu', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(64, (3, 3), activation='relu', padding='same') (p3)
c4 = Conv2D(64, (3, 3), activation='relu', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(128, (3, 3), activation='relu', padding='same') (p4)
c5 = Conv2D(128, (3, 3), activation='relu', padding='same') (c5)

u6 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(64, (3, 3), activation='relu', padding='same') (u6)
c6 = Conv2D(64, (3, 3), activation='relu', padding='same') (c6)

u7 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(32, (3, 3), activation='relu', padding='same') (u7)
c7 = Conv2D(32, (3, 3), activation='relu', padding='same') (c7)

u8 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(16, (3, 3), activation='relu', padding='same') (u8)
c8 = Conv2D(16, (3, 3), activation='relu', padding='same') (c8)

u9 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(8, (3, 3), activation='relu', padding='same') (u9)
c9 = Conv2D(8, (3, 3), activation='relu', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer = Adam(lr = 1e-4), loss='binary_crossentropy', metrics=[iou])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 256, 256, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 256, 256, 8)  224         lambda_3[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 256, 256, 8)  584         conv2d_39[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 128, 128, 8)  0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 128, 128, 16) 1168        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 128, 128, 16) 2320        conv2d_41[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 64, 64, 16)   0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 64, 64, 32)   4640        max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 64, 64, 32)   9248        conv2d_43[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 32, 32, 32)   0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 64)   18496       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 32, 64)   36928       conv2d_45[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 16, 16, 64)   0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 16, 16, 128)  73856       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 32, 32, 64)   32832       conv2d_48[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 32, 32, 128)  0           conv2d_transpose_9[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 32, 32, 64)   73792       concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 32, 32, 64)   36928       conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 64, 64, 32)   8224        conv2d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 64, 64, 64)   0           conv2d_transpose_10[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 64, 64, 32)   18464       concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 64, 64, 32)   9248        conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 128, 128, 16) 2064        conv2d_52[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 128, 128, 32) 0           conv2d_transpose_11[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 128, 128, 16) 4624        concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 128, 128, 16) 2320        conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 256, 256, 8)  520         conv2d_54[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 256, 256, 16) 0           conv2d_transpose_12[0][0]
#                                                                  conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 256, 256, 8)  1160        concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 256, 256, 8)  584         conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 256, 256, 1)  9           conv2d_56[0][0]
# ==================================================================================================
# Total params: 485,817
# Trainable params: 485,817
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Fit model
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model-dsbowl2018-1.h5', monitor='loss',verbose=1, save_best_only=True)
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=16, epochs=60, callbacks=[earlystopper, checkpointer])
# Out:
# Train on 603 samples, validate on 67 samples
# Epoch 1/30
# 603/603 [==============================] - 123s 204ms/step - loss: 0.6908 - mean_iou: 0.4209 - val_loss: 0.6853 - val_mean_iou: 0.4272
#
# Epoch 00001: loss improved from inf to 0.69082, saving model to model-dsbowl2018-1.h5
# Epoch 2/30
# 603/603 [==============================] - 114s 189ms/step - loss: 0.5543 - mean_iou: 0.4272 - val_loss: 0.4304 - val_mean_iou: 0.4262
#
# Epoch 00002: loss improved from 0.69082 to 0.55432, saving model to model-dsbowl2018-1.h5
# Epoch 3/30
# 603/603 [==============================] - 113s 187ms/step - loss: 0.4339 - mean_iou: 0.4260 - val_loss: 0.4053 - val_mean_iou: 0.4257
#
# Epoch 00003: loss improved from 0.55432 to 0.43391, saving model to model-dsbowl2018-1.h5
# Epoch 4/30
# 603/603 [==============================] - 114s 188ms/step - loss: 0.4149 - mean_iou: 0.4253 - val_loss: 0.3887 - val_mean_iou: 0.4254
#
# Epoch 00004: loss improved from 0.43391 to 0.41491, saving model to model-dsbowl2018-1.h5
# Epoch 5/30
# 603/603 [==============================] - 115s 190ms/step - loss: 0.3804 - mean_iou: 0.4253 - val_loss: 0.3358 - val_mean_iou: 0.4252
#
# Epoch 00005: loss improved from 0.41491 to 0.38037, saving model to model-dsbowl2018-1.h5
# Epoch 6/30
# 603/603 [==============================] - 116s 193ms/step - loss: 0.2815 - mean_iou: 0.4251 - val_loss: 0.2229 - val_mean_iou: 0.4251
#
# Epoch 00006: loss improved from 0.38037 to 0.28149, saving model to model-dsbowl2018-1.h5
# Epoch 7/30
# 603/603 [==============================] - 123s 203ms/step - loss: 0.2207 - mean_iou: 0.4251 - val_loss: 0.1936 - val_mean_iou: 0.4262
#
# Epoch 00007: loss improved from 0.28149 to 0.22071, saving model to model-dsbowl2018-1.h5
# Epoch 8/30
# 603/603 [==============================] - 126s 209ms/step - loss: 0.1790 - mean_iou: 0.4366 - val_loss: 0.1584 - val_mean_iou: 0.4499
#
# Epoch 00008: loss improved from 0.22071 to 0.17899, saving model to model-dsbowl2018-1.h5
# Epoch 9/30
# 603/603 [==============================] - 114s 189ms/step - loss: 0.1553 - mean_iou: 0.4641 - val_loss: 0.1453 - val_mean_iou: 0.4774
#
# Epoch 00009: loss improved from 0.17899 to 0.15529, saving model to model-dsbowl2018-1.h5
# Epoch 10/30
# 603/603 [==============================] - 115s 191ms/step - loss: 0.1437 - mean_iou: 0.4899 - val_loss: 0.1340 - val_mean_iou: 0.5019
#
# Epoch 00010: loss improved from 0.15529 to 0.14374, saving model to model-dsbowl2018-1.h5
# Epoch 11/30
# 603/603 [==============================] - 115s 191ms/step - loss: 0.1359 - mean_iou: 0.5126 - val_loss: 0.1284 - val_mean_iou: 0.5228
#
# Epoch 00011: loss improved from 0.14374 to 0.13588, saving model to model-dsbowl2018-1.h5
# Epoch 12/30
# 603/603 [==============================] - 115s 191ms/step - loss: 0.1270 - mean_iou: 0.5324 - val_loss: 0.1167 - val_mean_iou: 0.5416
#
# Epoch 00012: loss improved from 0.13588 to 0.12702, saving model to model-dsbowl2018-1.h5
# Epoch 13/30
# 603/603 [==============================] - 117s 194ms/step - loss: 0.1239 - mean_iou: 0.5501 - val_loss: 0.1164 - val_mean_iou: 0.5582
#
# Epoch 00013: loss improved from 0.12702 to 0.12386, saving model to model-dsbowl2018-1.h5
# Epoch 14/30
# 603/603 [==============================] - 121s 200ms/step - loss: 0.1200 - mean_iou: 0.5657 - val_loss: 0.1096 - val_mean_iou: 0.5728
#
# Epoch 00014: loss improved from 0.12386 to 0.12001, saving model to model-dsbowl2018-1.h5
# Epoch 15/30
# 603/603 [==============================] - 120s 199ms/step - loss: 0.1138 - mean_iou: 0.5798 - val_loss: 0.1052 - val_mean_iou: 0.5863
#
# Epoch 00015: loss improved from 0.12001 to 0.11383, saving model to model-dsbowl2018-1.h5
# Epoch 16/30
# 603/603 [==============================] - 132s 218ms/step - loss: 0.1148 - mean_iou: 0.5925 - val_loss: 0.1032 - val_mean_iou: 0.5982
#
# Epoch 00016: loss did not improve from 0.11383
# Epoch 17/30
# 603/603 [==============================] - 133s 220ms/step - loss: 0.1123 - mean_iou: 0.6037 - val_loss: 0.1121 - val_mean_iou: 0.6089
#
# Epoch 00017: loss improved from 0.11383 to 0.11232, saving model to model-dsbowl2018-1.h5
# Epoch 18/30
# 603/603 [==============================] - 134s 223ms/step - loss: 0.1082 - mean_iou: 0.6140 - val_loss: 0.1004 - val_mean_iou: 0.6189
#
# Epoch 00018: loss improved from 0.11232 to 0.10815, saving model to model-dsbowl2018-1.h5
# Epoch 19/30
# 603/603 [==============================] - 148s 245ms/step - loss: 0.1071 - mean_iou: 0.6235 - val_loss: 0.1022 - val_mean_iou: 0.6278
#
# Epoch 00019: loss improved from 0.10815 to 0.10713, saving model to model-dsbowl2018-1.h5
# Epoch 20/30
# 603/603 [==============================] - 169s 280ms/step - loss: 0.1097 - mean_iou: 0.6319 - val_loss: 0.0959 - val_mean_iou: 0.6357
#
# Epoch 00020: loss did not improve from 0.10713
# Epoch 21/30
# 603/603 [==============================] - 199s 330ms/step - loss: 0.1032 - mean_iou: 0.6395 - val_loss: 0.0940 - val_mean_iou: 0.6433
#
# Epoch 00021: loss improved from 0.10713 to 0.10322, saving model to model-dsbowl2018-1.h5
# Epoch 22/30
# 603/603 [==============================] - 153s 253ms/step - loss: 0.1001 - mean_iou: 0.6470 - val_loss: 0.1013 - val_mean_iou: 0.6505
#
# Epoch 00022: loss improved from 0.10322 to 0.10011, saving model to model-dsbowl2018-1.h5
# Epoch 23/30
# 603/603 [==============================] - 123s 204ms/step - loss: 0.0977 - mean_iou: 0.6536 - val_loss: 0.0920 - val_mean_iou: 0.6571
#
# Epoch 00023: loss improved from 0.10011 to 0.09775, saving model to model-dsbowl2018-1.h5
# Epoch 24/30
# 603/603 [==============================] - 124s 206ms/step - loss: 0.0970 - mean_iou: 0.6603 - val_loss: 0.0919 - val_mean_iou: 0.6635
#
# Epoch 00024: loss improved from 0.09775 to 0.09700, saving model to model-dsbowl2018-1.h5
# Epoch 25/30
# 603/603 [==============================] - 124s 205ms/step - loss: 0.0963 - mean_iou: 0.6667 - val_loss: 0.0924 - val_mean_iou: 0.6695
#
# Epoch 00025: loss improved from 0.09700 to 0.09629, saving model to model-dsbowl2018-1.h5
# Epoch 26/30
# 603/603 [==============================] - 124s 206ms/step - loss: 0.0968 - mean_iou: 0.6724 - val_loss: 0.0885 - val_mean_iou: 0.6750
#
# Epoch 00026: loss did not improve from 0.09629
# Epoch 27/30
# 603/603 [==============================] - 124s 206ms/step - loss: 0.0938 - mean_iou: 0.6776 - val_loss: 0.0877 - val_mean_iou: 0.6801
#
# Epoch 00027: loss improved from 0.09629 to 0.09383, saving model to model-dsbowl2018-1.h5
# Epoch 28/30
# 603/603 [==============================] - 121s 201ms/step - loss: 0.0930 - mean_iou: 0.6826 - val_loss: 0.0869 - val_mean_iou: 0.6850
#
# Epoch 00028: loss improved from 0.09383 to 0.09300, saving model to model-dsbowl2018-1.h5
# Epoch 29/30
# 603/603 [==============================] - 126s 208ms/step - loss: 0.0908 - mean_iou: 0.6874 - val_loss: 0.0846 - val_mean_iou: 0.6897
#
# Epoch 00029: loss improved from 0.09300 to 0.09077, saving model to model-dsbowl2018-1.h5
# Epoch 30/30
# 603/603 [==============================] - 123s 204ms/step - loss: 0.0908 - mean_iou: 0.6920 - val_loss: 0.0873 - val_mean_iou: 0.6941
#
# Epoch 00030: loss did not improve from 0.09077

# %%
# Dataset statistics epoch / loss and epoch / acc

#plt.figure(1,figsize=(7,5))

plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])

plt.title('train_loss vs val_loss')

plt.xlabel('epochs')
plt.ylabel('loss')

plt.grid(True)
plt.legend(['train','val'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f2f1ba97e284> in <module>()
#       4 #plt.figure(1,figsize=(7,5))
#       5
# ----> 6 plt.plot(results.history['loss'])
#       7 plt.plot(results.history['val_loss'])
#       8
#
# NameError: name 'results' is not defined

# %%
# Predict on train, val and test
model = load_model('model-dsbowl2018-1.h5', custom_objects={'mean_iou': mean_iou})
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-7f8b292c697d> in <module>()
#       1 # Predict on train, val and test
#       2 model = load_model('model-dsbowl2018-1.h5', custom_objects={'mean_iou': mean_iou})
# ----> 3 preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
#       4 preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
#       5 preds_test = model.predict(X_test, verbose=1)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1815         x = _standardize_input_data(x, self._feed_input_names,
#    1816                                     self._feed_input_shapes,
# -> 1817                                     check_batch_axis=False)
#    1818         if self.stateful:
#    1819             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     121                             ': expected ' + names[i] + ' to have shape ' +
#     122                             str(shape) + ' but got array with shape ' +
# --> 123                             str(data_shape))
#     124     return data
#     125
#
# ValueError: Error when checking : expected input_1 to have shape (512, 512, 3) but got array with shape (256, 256, 3)

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d57c97e424d5> in <module>()
#       1 # Perform a sanity check on some random training samples
# ----> 2 ix = random.randint(0, len(preds_train_t))
#       3 imshow(X_train[ix])
#       4 plt.show()
#       5 imshow(np.squeeze(Y_train[ix]))
#
# NameError: name 'preds_train_t' is not defined

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
imshow(X_train[int(X_train.shape[0]*0.9):][ix])
plt.show()
imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_val_t[ix]))
plt.show()
# Out:
# /Users/wajdiahmed/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
# Run-length encoding stolen from https://www.kaggle.com/rakhlin/fast-run-length-encoding-python
def rle_encoding(x):
    dots = np.where(x.T.flatten() == 1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    return run_lengths

def prob_to_rles(x, cutoff=0.5):
    lab_img = label(x > cutoff)
    for i in range(1, lab_img.max() + 1):
        yield rle_encoding(lab_img == i)

# %%
new_test_ids = []
rles = []
for n, id_ in enumerate(test_ids):
    rle = list(prob_to_rles(preds_test_upsampled[n]))
    rles.extend(rle)
    new_test_ids.extend([id_] * len(rle))

# %%
# Create submission DataFrame
sub = pd.DataFrame()
sub['ImageId'] = new_test_ids
sub['EncodedPixels'] = pd.Series(rles).apply(lambda x: ' '.join(str(y) for y in x))
sub.to_csv('sub-dsbowl2018-1.csv', index=False)
